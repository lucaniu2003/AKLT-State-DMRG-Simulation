# %%
using ITensors

# %% [markdown]
# # Basic DMRG

# %%
# Define the number of sites
N = 100
sites = siteinds("S=1/2",N)
@show sites[1]
# Out:
# sites[1] = (dim=2|id=50|"S=1/2,Site,n=1")
# (dim=2|id=50|"S=1/2,Site,n=1")

# %%
# Define Hamiltonian (nearest site spin-spin interaction)
os = OpSum() 
for j=1:N-1 
    os += "Sz",j,"Sz",j+1
    os += 1/2,"S+",j,"S-",j+1 
    os += 1/2,"S-",j,"S+",j+1 
end

# Generate an instance of this Hamiltonian
H = MPO(os,sites);

# Define the ansatz state
psi0 = randomMPS(sites; linkdims=10);

# %%
# Define the number of sweeps
sweeps = Sweeps(6) 

# Set the maximum bond dimension in each sweep
setmaxdim!(sweeps, 10,20,100,100,200,300) 

# Set the maximum truncation error 
setcutoff!(sweeps, 1E-11)

# %%
# Solve for ground state
energy, psi = dmrg(H,psi0, sweeps) 
println("G.S. energy = $energy")
# Out:
# After sweep 1 energy=-44.07669935740897  maxlinkdim=10 maxerr=2.91E-03 time=12.243
# After sweep 2 energy=-44.121721339320274  maxlinkdim=20 maxerr=1.52E-06 time=0.155
# After sweep 3 energy=-44.127567249572564  maxlinkdim=76 maxerr=9.94E-12 time=0.701
# After sweep 4 energy=-44.127734900930115  maxlinkdim=100 maxerr=4.16E-11 time=2.208
# After sweep 5 energy=-44.127739849763  maxlinkdim=132 maxerr=1.00E-11 time=3.071
# After sweep 6 energy=-44.127739890041276  maxlinkdim=146 maxerr=1.00E-11 time=4.620
# G.S. energy = -44.127739890041276

# %% [markdown]
# # Quantum Number Conserving DMRG

# %%
# Define sites, with conservation of quantum numbers turned on
N = 100
sites = siteinds("S=1",N;conserve_qns=true);

# %%
# Define Hamiltonian
os = OpSum()
for j=1:N-1
  os += "Sz",j,"Sz",j+1
  os += 1/2,"S+",j,"S-",j+1
  os += 1/2,"S-",j,"S+",j+1
end
H = MPO(os,sites);

# %%
# Define initial state, we have a alternating product state of up and down such that the total Sz=0
state = [isodd(n) ? "Up" : "Dn" for n=1:N]
psi0 = MPS(sites,state)
@show flux(psi0)
# Out:
# flux(psi0) = QN("Sz",0)
# QN("Sz",0)

# %%
# Set the maximum number of sweeps
nsweeps = 5

# Set the maximum bond dimension of each sweep
maxdim = [10,20,100,100,200]

# Set the maximum truncation error
cutoff = [1E-10]

# Solve for the GS energy
energy, psi = dmrg(H,psi0; nsweeps, maxdim, cutoff)
# Out:
# After sweep 1 energy=-138.32393649712677  maxlinkdim=9 maxerr=1.12E-15 time=21.429
# After sweep 2 energy=-138.93726652331463  maxlinkdim=20 maxerr=3.83E-06 time=1.303
# After sweep 3 energy=-138.94008403991265  maxlinkdim=91 maxerr=1.00E-10 time=1.800
# After sweep 4 energy=-138.94008607738797  maxlinkdim=100 maxerr=9.99E-11 time=2.663
# After sweep 5 energy=-138.9400860761833  maxlinkdim=95 maxerr=9.98E-11 time=2.492
# (-138.9400860761833, MPS
# [1] ((dim=3|id=399|"Link,l=1") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",2) => 1, (dim=3|id=583|"S=1,Site,n=1") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1)
# [2] ((dim=9|id=148|"Link,l=2") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 2
#  3: QN("Sz",0) => 3
#  4: QN("Sz",2) => 2
#  5: QN("Sz",4) => 1, (dim=3|id=228|"S=1,Site,n=2") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=3|id=399|"Link,l=1") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",2) => 1)
# [3] ((dim=3|id=117|"S=1,Site,n=3") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=27|id=566|"Link,l=3") <Out>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 3
#  3: QN("Sz",-2) => 6
#  4: QN("Sz",0) => 7
#  5: QN("Sz",2) => 6
#  6: QN("Sz",4) => 3
#  7: QN("Sz",6) => 1, (dim=9|id=148|"Link,l=2") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 2
#  3: QN("Sz",0) => 3
#  4: QN("Sz",2) => 2
#  5: QN("Sz",4) => 1)
# [4] ((dim=3|id=626|"S=1,Site,n=4") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=53|id=661|"Link,l=4") <Out>
#  1: QN("Sz",-6) => 2
#  2: QN("Sz",-4) => 8
#  3: QN("Sz",-2) => 13
#  4: QN("Sz",0) => 14
#  5: QN("Sz",2) => 10
#  6: QN("Sz",4) => 5
#  7: QN("Sz",6) => 1, (dim=27|id=566|"Link,l=3") <In>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 3
#  3: QN("Sz",-2) => 6
#  4: QN("Sz",0) => 7
#  5: QN("Sz",2) => 6
#  6: QN("Sz",4) => 3
#  7: QN("Sz",6) => 1)
# [5] ((dim=3|id=184|"S=1,Site,n=5") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=64|id=977|"Link,l=5") <Out>
#  1: QN("Sz",-6) => 2
#  2: QN("Sz",-4) => 8
#  3: QN("Sz",-2) => 16
#  4: QN("Sz",0) => 18
#  5: QN("Sz",2) => 13
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1, (dim=53|id=661|"Link,l=4") <In>
#  1: QN("Sz",-6) => 2
#  2: QN("Sz",-4) => 8
#  3: QN("Sz",-2) => 13
#  4: QN("Sz",0) => 14
#  5: QN("Sz",2) => 10
#  6: QN("Sz",4) => 5
#  7: QN("Sz",6) => 1)
# [6] ((dim=3|id=768|"S=1,Site,n=6") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=73|id=339|"Link,l=6") <Out>
#  1: QN("Sz",-6) => 3
#  2: QN("Sz",-4) => 10
#  3: QN("Sz",-2) => 18
#  4: QN("Sz",0) => 21
#  5: QN("Sz",2) => 14
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1, (dim=64|id=977|"Link,l=5") <In>
#  1: QN("Sz",-6) => 2
#  2: QN("Sz",-4) => 8
#  3: QN("Sz",-2) => 16
#  4: QN("Sz",0) => 18
#  5: QN("Sz",2) => 13
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1)
# [7] ((dim=3|id=897|"S=1,Site,n=7") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=78|id=878|"Link,l=7") <Out>
#  1: QN("Sz",-6) => 3
#  2: QN("Sz",-4) => 11
#  3: QN("Sz",-2) => 20
#  4: QN("Sz",0) => 22
#  5: QN("Sz",2) => 15
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1, (dim=73|id=339|"Link,l=6") <In>
#  1: QN("Sz",-6) => 3
#  2: QN("Sz",-4) => 10
#  3: QN("Sz",-2) => 18
#  4: QN("Sz",0) => 21
#  5: QN("Sz",2) => 14
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1)
# [8] ((dim=3|id=734|"S=1,Site,n=8") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=83|id=130|"Link,l=8") <Out>
#  1: QN("Sz",-6) => 4
#  2: QN("Sz",-4) => 12
#  3: QN("Sz",-2) => 21
#  4: QN("Sz",0) => 23
#  5: QN("Sz",2) => 16
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1, (dim=78|id=878|"Link,l=7") <In>
#  1: QN("Sz",-6) => 3
#  2: QN("Sz",-4) => 11
#  3: QN("Sz",-2) => 20
#  4: QN("Sz",0) => 22
#  5: QN("Sz",2) => 15
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1)
# [9] ((dim=3|id=728|"S=1,Site,n=9") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=86|id=122|"Link,l=9") <Out>
#  1: QN("Sz",-6) => 4
#  2: QN("Sz",-4) => 13
#  3: QN("Sz",-2) => 21
#  4: QN("Sz",0) => 24
#  5: QN("Sz",2) => 16
#  6: QN("Sz",4) => 7
#  7: QN("Sz",6) => 1, (dim=83|id=130|"Link,l=8") <In>
#  1: QN("Sz",-6) => 4
#  2: QN("Sz",-4) => 12
#  3: QN("Sz",-2) => 21
#  4: QN("Sz",0) => 23
#  5: QN("Sz",2) => 16
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1)
# [10] ((dim=3|id=337|"S=1,Site,n=10") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=89|id=633|"Link,l=10") <Out>
#  1: QN("Sz",-6) => 4
#  2: QN("Sz",-4) => 13
#  3: QN("Sz",-2) => 23
#  4: QN("Sz",0) => 24
#  5: QN("Sz",2) => 17
#  6: QN("Sz",4) => 7
#  7: QN("Sz",6) => 1, (dim=86|id=122|"Link,l=9") <In>
#  1: QN("Sz",-6) => 4
#  2: QN("Sz",-4) => 13
#  3: QN("Sz",-2) => 21
#  4: QN("Sz",0) => 24
#  5: QN("Sz",2) => 16
#  6: QN("Sz",4) => 7
#  7: QN("Sz",6) => 1)
# [11] ((dim=3|id=353|"S=1,Site,n=11") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=91|id=637|"Link,l=11") <Out>
#  1: QN("Sz",-6) => 5
#  2: QN("Sz",-4) => 13
#  3: QN("Sz",-2) => 23
#  4: QN("Sz",0) => 25
#  5: QN("Sz",2) => 17
#  6: QN("Sz",4) => 7
#  7: QN("Sz",6) => 1, (dim=89|id=633|"Link,l=10") <In>
#  1: QN("Sz",-6) => 4
#  2: QN("Sz",-4) => 13
#  3: QN("Sz",-2) => 23
#  4: QN("Sz",0) => 24
#  5: QN("Sz",2) => 17
#  6: QN("Sz",4) => 7
#  7: QN("Sz",6) => 1)
# [12] ((dim=3|id=422|"S=1,Site,n=12") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=93|id=723|"Link,l=12") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 5
#  3: QN("Sz",-4) => 14
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1, (dim=91|id=637|"Link,l=11") <In>
#  1: QN("Sz",-6) => 5
#  2: QN("Sz",-4) => 13
#  3: QN("Sz",-2) => 23
#  4: QN("Sz",0) => 25
#  5: QN("Sz",2) => 17
#  6: QN("Sz",4) => 7
#  7: QN("Sz",6) => 1)
# [13] ((dim=3|id=463|"S=1,Site,n=13") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=94|id=993|"Link,l=13") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 14
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1, (dim=93|id=723|"Link,l=12") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 5
#  3: QN("Sz",-4) => 14
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1)
# [14] ((dim=3|id=161|"S=1,Site,n=14") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=95|id=113|"Link,l=14") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1, (dim=94|id=993|"Link,l=13") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 14
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1)
# [15] ((dim=3|id=860|"S=1,Site,n=15") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=95|id=569|"Link,l=15") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1, (dim=95|id=113|"Link,l=14") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1)
# [16] ((dim=3|id=723|"S=1,Site,n=16") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=95|id=40|"Link,l=16") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 14
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1, (dim=95|id=569|"Link,l=15") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1)
# [17] ((dim=3|id=667|"S=1,Site,n=17") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=95|id=293|"Link,l=17") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 14
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1, (dim=95|id=40|"Link,l=16") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 14
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1)
# [18] ((dim=3|id=481|"S=1,Site,n=18") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=95|id=880|"Link,l=18") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=95|id=293|"Link,l=17") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 14
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1)
# [19] ((dim=3|id=996|"S=1,Site,n=19") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=95|id=809|"Link,l=19") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=95|id=880|"Link,l=18") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [20] ((dim=3|id=212|"S=1,Site,n=20") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=94|id=965|"Link,l=20") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 16
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=95|id=809|"Link,l=19") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [21] ((dim=3|id=509|"S=1,Site,n=21") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=94|id=273|"Link,l=21") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 16
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=94|id=965|"Link,l=20") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 16
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [22] ((dim=3|id=364|"S=1,Site,n=22") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=94|id=829|"Link,l=22") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 16
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=94|id=273|"Link,l=21") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 16
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [23] ((dim=3|id=685|"S=1,Site,n=23") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=93|id=229|"Link,l=23") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=94|id=829|"Link,l=22") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 16
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [24] ((dim=3|id=566|"S=1,Site,n=24") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=93|id=329|"Link,l=24") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=93|id=229|"Link,l=23") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [25] ((dim=3|id=253|"S=1,Site,n=25") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=92|id=180|"Link,l=25") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 24
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=93|id=329|"Link,l=24") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [26] ((dim=3|id=694|"S=1,Site,n=26") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=92|id=896|"Link,l=26") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 24
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=92|id=180|"Link,l=25") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 24
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [27] ((dim=3|id=925|"S=1,Site,n=27") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=91|id=122|"Link,l=27") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 24
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=92|id=896|"Link,l=26") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 24
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [28] ((dim=3|id=640|"S=1,Site,n=28") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=91|id=616|"Link,l=28") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 24
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=91|id=122|"Link,l=27") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 24
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [29] ((dim=3|id=806|"S=1,Site,n=29") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=856|"Link,l=29") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=91|id=616|"Link,l=28") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 24
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [30] ((dim=3|id=887|"S=1,Site,n=30") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=629|"Link,l=30") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=856|"Link,l=29") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [31] ((dim=3|id=355|"S=1,Site,n=31") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=564|"Link,l=31") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=629|"Link,l=30") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [32] ((dim=3|id=855|"S=1,Site,n=32") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=670|"Link,l=32") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=564|"Link,l=31") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [33] ((dim=3|id=309|"S=1,Site,n=33") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=149|"Link,l=33") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=670|"Link,l=32") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [34] ((dim=3|id=639|"S=1,Site,n=34") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=462|"Link,l=34") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=149|"Link,l=33") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [35] ((dim=3|id=105|"S=1,Site,n=35") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=731|"Link,l=35") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=462|"Link,l=34") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [36] ((dim=3|id=754|"S=1,Site,n=36") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=209|"Link,l=36") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=731|"Link,l=35") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [37] ((dim=3|id=376|"S=1,Site,n=37") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=560|"Link,l=37") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=209|"Link,l=36") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [38] ((dim=3|id=154|"S=1,Site,n=38") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=632|"Link,l=38") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=560|"Link,l=37") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [39] ((dim=3|id=160|"S=1,Site,n=39") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=267|"Link,l=39") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=632|"Link,l=38") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [40] ((dim=3|id=629|"S=1,Site,n=40") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=350|"Link,l=40") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=267|"Link,l=39") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [41] ((dim=3|id=426|"S=1,Site,n=41") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=906|"Link,l=41") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=350|"Link,l=40") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [42] ((dim=3|id=26|"S=1,Site,n=42") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=823|"Link,l=42") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=906|"Link,l=41") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [43] ((dim=3|id=55|"S=1,Site,n=43") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=617|"Link,l=43") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=823|"Link,l=42") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [44] ((dim=3|id=963|"S=1,Site,n=44") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=336|"Link,l=44") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=617|"Link,l=43") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [45] ((dim=3|id=326|"S=1,Site,n=45") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=415|"Link,l=45") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=336|"Link,l=44") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [46] ((dim=3|id=762|"S=1,Site,n=46") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=813|"Link,l=46") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=415|"Link,l=45") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [47] ((dim=3|id=783|"S=1,Site,n=47") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=492|"Link,l=47") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=813|"Link,l=46") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [48] ((dim=3|id=162|"S=1,Site,n=48") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=330|"Link,l=48") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=492|"Link,l=47") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [49] ((dim=3|id=868|"S=1,Site,n=49") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=722|"Link,l=49") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=330|"Link,l=48") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [50] ((dim=3|id=348|"S=1,Site,n=50") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=797|"Link,l=50") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=722|"Link,l=49") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [51] ((dim=3|id=479|"S=1,Site,n=51") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=496|"Link,l=51") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=797|"Link,l=50") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [52] ((dim=3|id=36|"S=1,Site,n=52") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=178|"Link,l=52") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=496|"Link,l=51") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [53] ((dim=3|id=279|"S=1,Site,n=53") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=416|"Link,l=53") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=178|"Link,l=52") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [54] ((dim=3|id=376|"S=1,Site,n=54") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=836|"Link,l=54") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=416|"Link,l=53") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [55] ((dim=3|id=778|"S=1,Site,n=55") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=942|"Link,l=55") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=836|"Link,l=54") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [56] ((dim=3|id=953|"S=1,Site,n=56") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=233|"Link,l=56") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=942|"Link,l=55") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [57] ((dim=3|id=962|"S=1,Site,n=57") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=312|"Link,l=57") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=233|"Link,l=56") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [58] ((dim=3|id=809|"S=1,Site,n=58") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=927|"Link,l=58") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=312|"Link,l=57") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [59] ((dim=3|id=416|"S=1,Site,n=59") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=735|"Link,l=59") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=927|"Link,l=58") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [60] ((dim=3|id=884|"S=1,Site,n=60") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=25|"Link,l=60") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=735|"Link,l=59") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [61] ((dim=3|id=11|"S=1,Site,n=61") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=683|"Link,l=61") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=25|"Link,l=60") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [62] ((dim=3|id=924|"S=1,Site,n=62") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=608|"Link,l=62") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=683|"Link,l=61") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [63] ((dim=3|id=486|"S=1,Site,n=63") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=52|"Link,l=63") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=608|"Link,l=62") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [64] ((dim=3|id=474|"S=1,Site,n=64") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=595|"Link,l=64") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=52|"Link,l=63") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [65] ((dim=3|id=609|"S=1,Site,n=65") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=338|"Link,l=65") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=595|"Link,l=64") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [66] ((dim=3|id=183|"S=1,Site,n=66") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=119|"Link,l=66") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=338|"Link,l=65") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [67] ((dim=3|id=926|"S=1,Site,n=67") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=507|"Link,l=67") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=119|"Link,l=66") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [68] ((dim=3|id=884|"S=1,Site,n=68") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=977|"Link,l=68") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=507|"Link,l=67") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [69] ((dim=3|id=369|"S=1,Site,n=69") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=195|"Link,l=69") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=977|"Link,l=68") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [70] ((dim=3|id=107|"S=1,Site,n=70") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=90|id=350|"Link,l=70") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=195|"Link,l=69") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [71] ((dim=3|id=398|"S=1,Site,n=71") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=91|id=896|"Link,l=71") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 16
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=90|id=350|"Link,l=70") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [72] ((dim=3|id=104|"S=1,Site,n=72") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=91|id=816|"Link,l=72") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 24
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=91|id=896|"Link,l=71") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 23
#  6: QN("Sz",2) => 16
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [73] ((dim=3|id=271|"S=1,Site,n=73") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=92|id=269|"Link,l=73") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 24
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=91|id=816|"Link,l=72") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 24
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [74] ((dim=3|id=405|"S=1,Site,n=74") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=92|id=627|"Link,l=74") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 24
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=92|id=269|"Link,l=73") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 24
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [75] ((dim=3|id=415|"S=1,Site,n=75") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=92|id=132|"Link,l=75") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 24
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=92|id=627|"Link,l=74") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 24
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [76] ((dim=3|id=999|"S=1,Site,n=76") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=93|id=766|"Link,l=76") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=92|id=132|"Link,l=75") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 24
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [77] ((dim=3|id=18|"S=1,Site,n=77") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=93|id=123|"Link,l=77") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=93|id=766|"Link,l=76") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [78] ((dim=3|id=768|"S=1,Site,n=78") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=94|id=932|"Link,l=78") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 16
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=93|id=123|"Link,l=77") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 15
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [79] ((dim=3|id=663|"S=1,Site,n=79") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=94|id=852|"Link,l=79") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 16
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=94|id=932|"Link,l=78") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 16
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [80] ((dim=3|id=308|"S=1,Site,n=80") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=94|id=207|"Link,l=80") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 16
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=94|id=852|"Link,l=79") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 16
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [81] ((dim=3|id=8|"S=1,Site,n=81") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=95|id=611|"Link,l=81") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=94|id=207|"Link,l=80") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 16
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [82] ((dim=3|id=861|"S=1,Site,n=82") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=95|id=549|"Link,l=82") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1, (dim=95|id=611|"Link,l=81") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [83] ((dim=3|id=863|"S=1,Site,n=83") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=95|id=126|"Link,l=83") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 14
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1, (dim=95|id=549|"Link,l=82") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 6
#  8: QN("Sz",6) => 1)
# [84] ((dim=3|id=557|"S=1,Site,n=84") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=95|id=442|"Link,l=84") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 14
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1, (dim=95|id=126|"Link,l=83") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 14
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1)
# [85] ((dim=3|id=383|"S=1,Site,n=85") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=95|id=247|"Link,l=85") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1, (dim=95|id=442|"Link,l=84") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 14
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1)
# [86] ((dim=3|id=241|"S=1,Site,n=86") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=95|id=321|"Link,l=86") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 14
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1, (dim=95|id=247|"Link,l=85") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1)
# [87] ((dim=3|id=199|"S=1,Site,n=87") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=94|id=854|"Link,l=87") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 14
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1, (dim=95|id=321|"Link,l=86") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 14
#  4: QN("Sz",-2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1)
# [88] ((dim=3|id=275|"S=1,Site,n=88") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=93|id=905|"Link,l=88") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 5
#  3: QN("Sz",-4) => 14
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1, (dim=94|id=854|"Link,l=87") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 6
#  3: QN("Sz",-4) => 14
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1)
# [89] ((dim=3|id=16|"S=1,Site,n=89") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=91|id=319|"Link,l=89") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 4
#  3: QN("Sz",-4) => 13
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1, (dim=93|id=905|"Link,l=88") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 5
#  3: QN("Sz",-4) => 14
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1)
# [90] ((dim=3|id=965|"S=1,Site,n=90") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=89|id=754|"Link,l=90") <Out>
#  1: QN("Sz",-6) => 4
#  2: QN("Sz",-4) => 13
#  3: QN("Sz",-2) => 23
#  4: QN("Sz",0) => 24
#  5: QN("Sz",2) => 17
#  6: QN("Sz",4) => 7
#  7: QN("Sz",6) => 1, (dim=91|id=319|"Link,l=89") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 4
#  3: QN("Sz",-4) => 13
#  4: QN("Sz",-2) => 23
#  5: QN("Sz",0) => 25
#  6: QN("Sz",2) => 17
#  7: QN("Sz",4) => 7
#  8: QN("Sz",6) => 1)
# [91] ((dim=3|id=180|"S=1,Site,n=91") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=86|id=11|"Link,l=91") <Out>
#  1: QN("Sz",-6) => 4
#  2: QN("Sz",-4) => 13
#  3: QN("Sz",-2) => 21
#  4: QN("Sz",0) => 24
#  5: QN("Sz",2) => 16
#  6: QN("Sz",4) => 7
#  7: QN("Sz",6) => 1, (dim=89|id=754|"Link,l=90") <In>
#  1: QN("Sz",-6) => 4
#  2: QN("Sz",-4) => 13
#  3: QN("Sz",-2) => 23
#  4: QN("Sz",0) => 24
#  5: QN("Sz",2) => 17
#  6: QN("Sz",4) => 7
#  7: QN("Sz",6) => 1)
# [92] ((dim=3|id=2|"S=1,Site,n=92") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=83|id=324|"Link,l=92") <Out>
#  1: QN("Sz",-6) => 4
#  2: QN("Sz",-4) => 12
#  3: QN("Sz",-2) => 21
#  4: QN("Sz",0) => 23
#  5: QN("Sz",2) => 16
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1, (dim=86|id=11|"Link,l=91") <In>
#  1: QN("Sz",-6) => 4
#  2: QN("Sz",-4) => 13
#  3: QN("Sz",-2) => 21
#  4: QN("Sz",0) => 24
#  5: QN("Sz",2) => 16
#  6: QN("Sz",4) => 7
#  7: QN("Sz",6) => 1)
# [93] ((dim=3|id=566|"S=1,Site,n=93") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=78|id=838|"Link,l=93") <Out>
#  1: QN("Sz",-6) => 3
#  2: QN("Sz",-4) => 11
#  3: QN("Sz",-2) => 20
#  4: QN("Sz",0) => 22
#  5: QN("Sz",2) => 15
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1, (dim=83|id=324|"Link,l=92") <In>
#  1: QN("Sz",-6) => 4
#  2: QN("Sz",-4) => 12
#  3: QN("Sz",-2) => 21
#  4: QN("Sz",0) => 23
#  5: QN("Sz",2) => 16
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1)
# [94] ((dim=3|id=696|"S=1,Site,n=94") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=73|id=669|"Link,l=94") <Out>
#  1: QN("Sz",-6) => 3
#  2: QN("Sz",-4) => 10
#  3: QN("Sz",-2) => 18
#  4: QN("Sz",0) => 21
#  5: QN("Sz",2) => 14
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1, (dim=78|id=838|"Link,l=93") <In>
#  1: QN("Sz",-6) => 3
#  2: QN("Sz",-4) => 11
#  3: QN("Sz",-2) => 20
#  4: QN("Sz",0) => 22
#  5: QN("Sz",2) => 15
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1)
# [95] ((dim=3|id=989|"S=1,Site,n=95") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=64|id=106|"Link,l=95") <Out>
#  1: QN("Sz",-6) => 2
#  2: QN("Sz",-4) => 8
#  3: QN("Sz",-2) => 16
#  4: QN("Sz",0) => 18
#  5: QN("Sz",2) => 13
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1, (dim=73|id=669|"Link,l=94") <In>
#  1: QN("Sz",-6) => 3
#  2: QN("Sz",-4) => 10
#  3: QN("Sz",-2) => 18
#  4: QN("Sz",0) => 21
#  5: QN("Sz",2) => 14
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1)
# [96] ((dim=3|id=889|"S=1,Site,n=96") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=53|id=457|"Link,l=96") <Out>
#  1: QN("Sz",-6) => 2
#  2: QN("Sz",-4) => 8
#  3: QN("Sz",-2) => 13
#  4: QN("Sz",0) => 14
#  5: QN("Sz",2) => 10
#  6: QN("Sz",4) => 5
#  7: QN("Sz",6) => 1, (dim=64|id=106|"Link,l=95") <In>
#  1: QN("Sz",-6) => 2
#  2: QN("Sz",-4) => 8
#  3: QN("Sz",-2) => 16
#  4: QN("Sz",0) => 18
#  5: QN("Sz",2) => 13
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1)
# [97] ((dim=3|id=52|"S=1,Site,n=97") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=27|id=26|"Link,l=97") <Out>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 3
#  3: QN("Sz",-2) => 6
#  4: QN("Sz",0) => 7
#  5: QN("Sz",2) => 6
#  6: QN("Sz",4) => 3
#  7: QN("Sz",6) => 1, (dim=53|id=457|"Link,l=96") <In>
#  1: QN("Sz",-6) => 2
#  2: QN("Sz",-4) => 8
#  3: QN("Sz",-2) => 13
#  4: QN("Sz",0) => 14
#  5: QN("Sz",2) => 10
#  6: QN("Sz",4) => 5
#  7: QN("Sz",6) => 1)
# [98] ((dim=3|id=593|"S=1,Site,n=98") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=9|id=742|"Link,l=98") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 2
#  3: QN("Sz",0) => 3
#  4: QN("Sz",2) => 2
#  5: QN("Sz",4) => 1, (dim=27|id=26|"Link,l=97") <In>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 3
#  3: QN("Sz",-2) => 6
#  4: QN("Sz",0) => 7
#  5: QN("Sz",2) => 6
#  6: QN("Sz",4) => 3
#  7: QN("Sz",6) => 1)
# [99] ((dim=3|id=970|"S=1,Site,n=99") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=3|id=607|"Link,l=99") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",2) => 1, (dim=9|id=742|"Link,l=98") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 2
#  3: QN("Sz",0) => 3
#  4: QN("Sz",2) => 2
#  5: QN("Sz",4) => 1)
# [100] ((dim=3|id=380|"S=1,Site,n=100") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=3|id=607|"Link,l=99") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",2) => 1)
# )

# %%
# Verify the conservation of Sz
@show flux(psi)
# Out:
# flux(psi) = QN("Sz",0)
# QN("Sz",0)

# %% [markdown]
# # AKLT Ground State Simulation

# %%
# Define the number of sites
N = 30
sites = siteinds("S=1",N);

# %%
# Define Hamiltonian (nearest site spin-spin interaction)
os = OpSum() 
for j=1:N-1 
    # S*S Terms
    # Sz Sz
    os += "Sz", j, "Sz", j+1

    # S+ S- and S- S+
    os += 1/2, "S+", j, "S-", j+1
    os += 1/2, "S-", j, "S+", j+1

    # Square terms in (S*S)^2
    # (1/3) * (Sz Sz)^2 term
    os += (1/3), "Sz", j, "Sz", j+1, "Sz", j, "Sz", j+1
    # (1/3) * (1/4) (S+ S- S+ S-) term
    os += (1/3) * (1/4), "S+", j, "S-", j+1, "S+", j, "S-", j+1
    os += (1/3) * (1/4), "S-", j, "S+", j+1, "S-", j, "S+", j+1

    # Cross terms in (S*S)^2
    # (1/3) * (1/2) Sz Sz S+ S- terms
    os += (1/3) * (1/2), "Sz", j, "Sz", j+1, "S+", j, "S-", j+1
    os += (1/3) * (1/2), "S+", j, "S-", j+1, "Sz", j, "Sz", j+1

    # (1/3) * (1/2) Sz Sz S- S+ terms
    os += (1/3) * (1/2), "Sz", j, "Sz", j+1, "S-", j, "S+", j+1
    os += (1/3) * (1/2), "S-", j, "S+", j+1, "Sz", j, "Sz", j+1

    # (1/3) * (1/4) S+ S- S- S+ terms
    os += (1/3) * (1/4), "S+", j, "S-", j+1, "S-", j, "S+", j+1
    os += (1/3) * (1/4), "S-", j, "S+", j+1, "S+", j, "S-", j+1
end

# Convert the OpSum to an MPO (Matrix Product Operator)
H_AKLT = MPO(os, sites);

# %%
# Define the ansatz state
psi0 = randomMPS(sites; linkdims=10);

# %%
# Set the maximum number of sweeps
nsweeps = 5

# Set the maximum bond dimension of each sweep
maxdim = [10,20,100,100,200]

# Set the maximum truncation error
cutoff = [1E-10]

# Solve for the GS energy
temp_energy, psi = dmrg(H_AKLT,psi0; nsweeps, maxdim, cutoff);
norm = inner(psi, psi);
energy = inner(psi', H_AKLT, psi)/norm
println("The ground state energy is", energy)
# Out:
# After sweep 1 energy=-32.648159947767454  maxlinkdim=10 maxerr=1.02E-02 time=0.135
# After sweep 2 energy=-32.66652506880712  maxlinkdim=20 maxerr=1.57E-08 time=0.297
# After sweep 3 energy=-32.66666484911889  maxlinkdim=12 maxerr=1.00E-10 time=0.156
# After sweep 4 energy=-32.66666666506971  maxlinkdim=4 maxerr=9.70E-11 time=0.050
# After sweep 5 energy=-32.66666666666668  maxlinkdim=2 maxerr=1.40E-12 time=0.039
# The ground state energy is-32.66666666666666

# %%
# Calculate the correlation of some operator between the ith and jth site
function Corr_ij(psi::MPS, operator1::String, operator2::String, i::Int64, j::Int64)
    # Get the number of sites from the MPS
    N = length(siteinds(psi))

    # Check if indices are within the valid range
    if i < 1 || i > N || j < 1 || j > N
        @warn "Indices i=$i and j=$j are out of bounds for the MPS with $N sites"
        return nothing
    end

    # Calculate the full correlation matrix
    Corr = correlation_matrix(psi, operator1, operator2)

    # Extract the corresponding element of correlation matrix
    return Corr[i, j]
end
# Out:
# Corr_ij (generic function with 1 method)

# %%
Corr_ij(psi, "Sz", "Sz", 4, 2)
# Out:
# 0.1481481481779856

# %% [markdown]
# # AKLT Exact Ground State

# %%
# Define the number of sites
N = 4

# Create physical indices for each site with dimension 3
phys_indices = [Index(3, "S=1, Site, n=$n") for n in 1:N]
#phys_indices = siteinds("S=1",N);

# Create bond indices with dimension 2 for a 1D chain
bond_indices = [Index(2, "Bond, n=$n") for n in 1:N]  # +1 to handle both ends

# Initialize a vector to store the MPS tensors
tensors = Vector{ITensor}(undef, N);

# %%
# Calculate the normalization factor
norm_factor = 2/sqrt(3)

# Define matrices corresponding to each physical index value, normalized
matrices = [ [0 1/sqrt(2) * norm_factor; 0 0],  # Matrix when physical index is 1, A+
             [-1/2 * norm_factor 0; 0 1/2 * norm_factor],  # Matrix when physical index is 2, A0
             [0 0; -1/sqrt(2) * norm_factor 0] ]  # Matrix when physical index is 3, A-

# To verify, let's print out the matrices
for (idx, mat) in enumerate(matrices)
    println("Matrix for physical index ", idx, ":")
    println(mat)
    println()  # Add an empty line for better readability
end
# Out:
# Matrix for physical index 1:
# [0.0 0.816496580927726; 0.0 0.0]
#
# Matrix for physical index 2:
# [-0.5773502691896258 0.0; 0.0 0.5773502691896258]
#
# Matrix for physical index 3:
# [0.0 0.0; -0.816496580927726 0.0]

# %%
# Assign matrix element to bulk sites
# Loop over each site
for n in 1:N
    tensors[n] = ITensor(bond_indices[(n-1)%N+1], phys_indices[n], bond_indices[(n)%N+1])
    #@show n, tensors[n]

    # Loop over physical index
    for p in 1:3
        
        # Loop over each element in the matrix
        for idx in CartesianIndices(matrices[p])
            # Access matrix element using idx and assign it to the tensor
            # Note the correction in the physical index access: should be phys_indices[n]
            # Tuple(idx)... splits the CartesianIndex into its component parts
            i, j = Tuple(idx)
            tensors[n][bond_indices[(n-1)%N+1] => i, phys_indices[n] => p, bond_indices[(n)%N+1] => j] = matrices[p][idx];
        end
    end
end

# %%
psi_exact = MPS(tensors);
#@show siteinds(psi_exact)
# Out:
# MPS
# [1] ((dim=2|id=300|"Bond,n=1"), (dim=3|id=614|"S=1,Site,n=1"), (dim=2|id=869|"Bond,n=2"))
# [2] ((dim=2|id=869|"Bond,n=2"), (dim=3|id=236|"S=1,Site,n=2"), (dim=2|id=950|"Bond,n=3"))
# [3] ((dim=2|id=950|"Bond,n=3"), (dim=3|id=844|"S=1,Site,n=3"), (dim=2|id=889|"Bond,n=4"))
# [4] ((dim=2|id=889|"Bond,n=4"), (dim=3|id=120|"S=1,Site,n=4"), (dim=2|id=300|"Bond,n=1"))

# %%
# Define Hamiltonian (nearest site spin-spin interaction)
os = OpSum() 
for j=1:N-1 
    # S*S Terms
    # Sz Sz
    os += "Sz", j, "Sz", j+1

    # S+ S- and S- S+
    os += 1/2, "S+", j, "S-", j+1
    os += 1/2, "S-", j, "S+", j+1

    # Square terms in (S*S)^2
    # (1/3) * (Sz Sz)^2 term
    os += (1/3), "Sz", j, "Sz", j+1, "Sz", j, "Sz", j+1
    # (1/3) * (1/4) (S+ S- S+ S-) term
    os += (1/3) * (1/4), "S+", j, "S-", j+1, "S+", j, "S-", j+1
    os += (1/3) * (1/4), "S-", j, "S+", j+1, "S-", j, "S+", j+1

    # Cross terms in (S*S)^2
    # (1/3) * (1/2) Sz Sz S+ S- terms
    os += (1/3) * (1/2), "Sz", j, "Sz", j+1, "S+", j, "S-", j+1
    os += (1/3) * (1/2), "S+", j, "S-", j+1, "Sz", j, "Sz", j+1

    # (1/3) * (1/2) Sz Sz S- S+ terms
    os += (1/3) * (1/2), "Sz", j, "Sz", j+1, "S-", j, "S+", j+1
    os += (1/3) * (1/2), "S-", j, "S+", j+1, "Sz", j, "Sz", j+1

    # (1/3) * (1/4) S+ S- S- S+ terms
    os += (1/3) * (1/4), "S+", j, "S-", j+1, "S-", j, "S+", j+1
    os += (1/3) * (1/4), "S-", j, "S+", j+1, "S+", j, "S-", j+1
end

# Convert the OpSum to an MPO (Matrix Product Operator)
H_AKLT = MPO(os, phys_indices)
# Out:
# MPO
# [1] ((dim=14|id=999|"Link,l=1"), (dim=3|id=614|"S=1,Site,n=1")', (dim=3|id=614|"S=1,Site,n=1"))
# [2] ((dim=14|id=999|"Link,l=1"), (dim=14|id=45|"Link,l=2"), (dim=3|id=236|"S=1,Site,n=2")', (dim=3|id=236|"S=1,Site,n=2"))
# [3] ((dim=14|id=45|"Link,l=2"), (dim=14|id=594|"Link,l=3"), (dim=3|id=844|"S=1,Site,n=3")', (dim=3|id=844|"S=1,Site,n=3"))
# [4] ((dim=14|id=594|"Link,l=3"), (dim=3|id=120|"S=1,Site,n=4")', (dim=3|id=120|"S=1,Site,n=4"))

# %%
# Contract MPS with MPO to get the expectation value
#@show psi_exact
#@show H_AKLT
temp_psi = apply(H_AKLT, psi_exact)
psi2 = temp_psi[1]*temp_psi[2]*temp_psi[3]*temp_psi[4]
psi1 =  psi_exact[1]*psi_exact[2]*psi_exact[3]*psi_exact[4]
#H = H_AKLT[1]*H_AKLT[2]*H_AKLT[3]*H_AKLT[4]
#@show psi1, psi2
@show psi1*psi2
#expectation_value = inner(psi_exact', H_AKLT, psi_exact);
#expectation_value = inner(psi_exact, apply(H_AKLT, psi_exact))
#println("Expectation value: ", expectation_value)
# Out:
# psi1 * psi2 = ITensor ord=0
# NDTensors.Dense{Float64, Vector{Float64}}
#  0-dimensional
# -2.074074074074074
# ITensor ord=0
# NDTensors.Dense{Float64, Vector{Float64}}
